# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np

Baltimore = pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
Boston = pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
NewYork = pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
Philly = pd.read_csv("dataset/philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
Baltimore.head()

Baltimore.clean = Baltimore.drop(["Grade", "Crop", "Storage", "Appearance", "Condition", "Quality", "Unit of Sale", "Environment", "Origin District", "Sub Variety", "Commodity Name", "Mostly Low", "Mostly High", "Trans Mode"], axis=1)
# Out:
#    City Name  Type       Package      Variety  Grade        Date  Low Price  \
# 0  BALTIMORE   NaN  24 inch bins          NaN    NaN  04/29/2017        270
# 1  BALTIMORE   NaN  24 inch bins          NaN    NaN  05/06/2017        270
# 2  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE    NaN  09/24/2016        160
# 3  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE    NaN  09/24/2016        160
# 4  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE    NaN  11/05/2016         90
#
#    High Price    Origin Item Size Color Repack
# 0       280.0       NaN       lge   NaN      E
# 1       280.0       NaN       lge   NaN      E
# 2       160.0  DELAWARE       med   NaN      N
# 3       160.0  VIRGINIA       med   NaN      N
# 4       100.0  MARYLAND       lge   NaN      N

# %%
Balti = Baltimore.clean.drop_duplicates()
Balti
# Out:
#      City Name  Type             Package      Variety  Grade        Date  \
# 0    BALTIMORE   NaN        24 inch bins          NaN    NaN  04/29/2017
# 1    BALTIMORE   NaN        24 inch bins          NaN    NaN  05/06/2017
# 2    BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  09/24/2016
# 3    BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  09/24/2016
# 4    BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  11/05/2016
# ..         ...   ...                 ...          ...    ...         ...
# 148  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE    NaN  09/30/2017
# 149  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE    NaN  09/30/2017
# 150  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE    NaN  09/24/2016
# 151  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE    NaN  10/01/2016
# 152  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE    NaN  10/08/2016
#
#      Low Price  High Price        Origin Item Size   Color Repack
# 0          270       280.0           NaN       lge     NaN      E
# 1          270       280.0           NaN       lge     NaN      E
# 2          160       160.0      DELAWARE       med     NaN      N
# 3          160       160.0      VIRGINIA       med     NaN      N
# 4           90       100.0      MARYLAND       lge     NaN      N
# ..         ...         ...           ...       ...     ...    ...
# 148         18        18.0      MARYLAND       NaN  ORANGE      N
# 149         18        18.0  PENNSYLVANIA       NaN  ORANGE      N
# 150         15        15.0      MARYLAND       sml     NaN      N
# 151         15        15.0      MARYLAND       sml     NaN      N
# 152         15        15.0      MARYLAND       sml     NaN      N
#
# [153 rows x 12 columns]

# %%
NewYork_clean = NewYork.drop(["Grade", "Crop", "Storage", "Appearance", "Condition", "Quality", "Unit of Sale", "Environment", "Origin District", "Sub Variety", "Commodity Name", "Mostly Low", "Mostly High", "Trans Mode"], axis=1)

NY= NewYork_clean.drop_duplicates()
NY
# Out:
#     City Name  Type              Package      Variety        Date  Low Price  \
# 0    NEW YORK   NaN         36 inch bins  HOWDEN TYPE  09/24/2016        150
# 1    NEW YORK   NaN         36 inch bins  HOWDEN TYPE  09/24/2016        150
# 2    NEW YORK   NaN         36 inch bins  HOWDEN TYPE  09/24/2016        130
# 3    NEW YORK   NaN         36 inch bins  HOWDEN TYPE  09/24/2016        130
# 4    NEW YORK   NaN         36 inch bins  HOWDEN TYPE  09/24/2016        120
# ..        ...   ...                  ...          ...         ...        ...
# 105  NEW YORK   NaN   1/2 bushel cartons    MINIATURE  09/23/2017         16
# 106  NEW YORK   NaN   1/2 bushel cartons    MINIATURE  09/30/2017         16
# 107  NEW YORK   NaN       bushel cartons    MINIATURE  09/09/2017         32
# 110  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE  10/15/2016         18
# 111  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE  10/15/2016         18
#
#      High Price      Origin Item Size Color Repack
# 0           170    MICHIGAN      xlge   NaN      N
# 1           170    MICHIGAN       lge   NaN      N
# 2           150  NEW JERSEY      xlge   NaN      N
# 3           150  NEW JERSEY       lge   NaN      N
# 4           140    NEW YORK   med-lge   NaN      N
# ..          ...         ...       ...   ...    ...
# 105          18        OHIO       sml   NaN      N
# 106          18        OHIO       sml   NaN      N
# 107          32        OHIO       sml   NaN      N
# 110          18    NEW YORK       med   NaN      N
# 111          18    NEW YORK       sml   NaN      N
#
# [110 rows x 11 columns]

# %%
Boston_clean = Boston.drop(["Grade", "Crop", "Storage", "Appearance", "Condition", "Quality", "Unit of Sale", "Environment", "Origin District", "Sub Variety", "Commodity Name", "Mostly Low", "Mostly High", "Trans Mode"], axis=1)
Boston_clean= Boston_clean.drop_duplicates()
Boston_clean
# Out:
#     City Name  Type             Package      Variety        Date  Low Price  \
# 0      BOSTON   NaN        36 inch bins  HOWDEN TYPE  09/24/2016        160
# 1      BOSTON   NaN        36 inch bins  HOWDEN TYPE  09/24/2016        160
# 2      BOSTON   NaN        36 inch bins  HOWDEN TYPE  09/24/2016        160
# 4      BOSTON   NaN        36 inch bins  HOWDEN TYPE  09/24/2016        160
# 6      BOSTON   NaN        36 inch bins  HOWDEN TYPE  09/24/2016        140
# ..        ...   ...                 ...          ...         ...        ...
# 333    BOSTON   NaN  1/2 bushel cartons    MINIATURE  10/22/2016         15
# 334    BOSTON   NaN  1/2 bushel cartons    MINIATURE  10/29/2016         15
# 335    BOSTON   NaN  1/2 bushel cartons    MINIATURE  10/29/2016         15
# 336    BOSTON   NaN  1/2 bushel cartons    MINIATURE  11/05/2016         15
# 337    BOSTON   NaN  1/2 bushel cartons    MINIATURE  11/05/2016         15
#
#      High Price         Origin Item Size   Color Repack
# 0           200         CANADA     exjbo  ORANGE      N
# 1           200         CANADA       jbo  ORANGE      N
# 2           200         CANADA      xlge  ORANGE      N
# 4           180         CANADA       lge  ORANGE      N
# 6           160         CANADA   med-lge  ORANGE      N
# ..          ...            ...       ...     ...    ...
# 333          18  MASSACHUSETTS       sml  ORANGE      N
# 334          18  MASSACHUSETTS       sml   WHITE      N
# 335          18  MASSACHUSETTS       sml  ORANGE      N
# 336          18  MASSACHUSETTS       sml  ORANGE      N
# 337          18  MASSACHUSETTS       sml   WHITE      N
#
# [330 rows x 11 columns]

# %%
Philly_clean = Philly.drop(["Grade", "Crop", "Storage", "Appearance", "Condition", "Quality", "Unit of Sale", "Environment", "Origin District", "Sub Variety", "Commodity Name", "Mostly Low", "Mostly High", "Trans Mode"], axis=1)
Philly_clean = Philly_clean.drop_duplicates()
Philly_clean
# Out:
#        City Name  Type               Package       Variety        Date  \
# 0   PHILADELPHIA   NaN          24 inch bins   HOWDEN TYPE  09/16/2017
# 1   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/24/2016
# 2   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/24/2016
# 3   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/24/2016
# 4   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/01/2016
# 5   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/01/2016
# 6   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/01/2016
# 7   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/08/2016
# 8   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/08/2016
# 9   PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/15/2016
# 10  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/15/2016
# 11  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/22/2016
# 12  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/22/2016
# 13  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/22/2016
# 14  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/22/2016
# 15  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/29/2016
# 16  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/29/2016
# 17  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/29/2016
# 18  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  10/29/2016
# 19  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/16/2017
# 20  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/16/2017
# 21  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/23/2017
# 22  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/23/2017
# 23  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/23/2017
# 24  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/23/2017
# 25  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/23/2017
# 26  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/30/2017
# 27  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE  09/30/2017
# 28  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  10/15/2016
# 29  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  10/22/2016
# 30  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  10/29/2016
# 31  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  08/26/2017
# 32  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  09/16/2017
# 33  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE  09/23/2017
# 34  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/01/2016
# 35  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/15/2016
# 36  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/22/2016
# 37  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/22/2016
# 38  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/29/2016
# 39  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  10/29/2016
# 40  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  09/23/2017
# 41  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  09/23/2017
# 42  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  09/23/2017
# 43  PHILADELPHIA   NaN          24 inch bins      PIE TYPE  09/30/2017
# 44  PHILADELPHIA   NaN          24 inch bins  KNUCKLE HEAD  10/08/2016
# 45  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  09/24/2016
# 46  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/01/2016
# 47  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/01/2016
# 48  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/08/2016
# 49  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/15/2016
# 50  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/22/2016
# 51  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  10/29/2016
# 52  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  11/05/2016
# 53  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  08/26/2017
# 54  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  09/16/2017
# 55  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  09/23/2017
# 56  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE  09/30/2017
#
#     Low Price  High Price        Origin Item Size  Color Repack
# 0         140         150  PENNSYLVANIA       lge    NaN      N
# 1         150         150      NEW YORK   med-lge    NaN      N
# 2         150         150      NEW YORK       med    NaN      N
# 3         150         160  PENNSYLVANIA       lge    NaN      N
# 4         140         140    NEW JERSEY   med-lge    NaN      N
# 5         140         140  PENNSYLVANIA   med-lge    NaN      N
# 6         120         120  PENNSYLVANIA       med    NaN      N
# 7         140         155    NEW JERSEY       med    NaN      N
# 8         120         120    NEW JERSEY       sml    NaN      N
# 9         120         125  PENNSYLVANIA       lge    NaN      N
# 10        100         125  PENNSYLVANIA       med    NaN      N
# 11        130         140    NEW JERSEY   med-lge    NaN      N
# 12        120         120  PENNSYLVANIA       lge    NaN      N
# 13        130         140  PENNSYLVANIA   med-lge    NaN      N
# 14        100         120  PENNSYLVANIA       med    NaN      N
# 15        130         140    NEW JERSEY   med-lge    NaN      N
# 16        120         120  PENNSYLVANIA       lge    NaN      N
# 17        130         140  PENNSYLVANIA   med-lge    NaN      N
# 18        100         120  PENNSYLVANIA       med    NaN      N
# 19        120         120  PENNSYLVANIA       lge    NaN      N
# 20        120         150  PENNSYLVANIA       med    NaN      N
# 21        140         140      DELAWARE       lge    NaN      N
# 22        150         150      DELAWARE       med    NaN      N
# 23        120         150      NEW YORK       lge    NaN      N
# 24        140         150  PENNSYLVANIA      xlge    NaN      N
# 25        140         150  PENNSYLVANIA       lge    NaN      N
# 26        140         140      DELAWARE       lge    NaN      N
# 27        140         140      DELAWARE       med    NaN      N
# 28         12          14          OHIO       med    NaN      N
# 29         12          12          OHIO       med    NaN      N
# 30         12          12          OHIO       med    NaN      N
# 31         18          20      MICHIGAN       med    NaN      N
# 32         18          18          OHIO       med    NaN      N
# 33         18          22          OHIO       med    NaN      N
# 34        250         250  PENNSYLVANIA       med    NaN      N
# 35        140         140  PENNSYLVANIA       med    NaN      N
# 36        140         150  PENNSYLVANIA       med    NaN      N
# 37         75         100  PENNSYLVANIA       sml    NaN      N
# 38        140         150  PENNSYLVANIA       med    NaN      N
# 39         75         100  PENNSYLVANIA       sml    NaN      N
# 40        180         180      DELAWARE       med    NaN      N
# 41        140         140      DELAWARE       sml    NaN      N
# 42        180         180      NEW YORK       med    NaN      N
# 43        140         140      DELAWARE       sml    NaN      N
# 44        210         210    NEW JERSEY       med    NaN      N
# 45         17          18          OHIO       NaN    NaN      N
# 46         18          18    NEW JERSEY       NaN    NaN      N
# 47         17          18          OHIO       NaN    NaN      N
# 48         15          15          OHIO       NaN    NaN      N
# 49         15          18          OHIO       NaN    NaN      N
# 50         16          18          OHIO       NaN    NaN      N
# 51         16          18          OHIO       NaN    NaN      N
# 52         16          18          OHIO       NaN    NaN      N
# 53         18          20      MICHIGAN       NaN    NaN      N
# 54         16          16          OHIO       NaN    NaN      N
# 55         15          16          OHIO       NaN    NaN      N
# 56         15          18          OHIO       NaN    NaN      N

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
Northeast = pd.concat([Balti, NY, Boston_clean, Philly_clean])
Northeast
# Out:
#        City Name  Type             Package      Variety  Grade        Date  \
# 0      BALTIMORE   NaN        24 inch bins          NaN    NaN  04/29/2017
# 1      BALTIMORE   NaN        24 inch bins          NaN    NaN  05/06/2017
# 2      BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  09/24/2016
# 3      BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  09/24/2016
# 4      BALTIMORE   NaN        24 inch bins  HOWDEN TYPE    NaN  11/05/2016
# ..           ...   ...                 ...          ...    ...         ...
# 52  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE    NaN  11/05/2016
# 53  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE    NaN  08/26/2017
# 54  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE    NaN  09/16/2017
# 55  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE    NaN  09/23/2017
# 56  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE    NaN  09/30/2017
#
#     Low Price  High Price    Origin Item Size Color Repack
# 0         270       280.0       NaN       lge   NaN      E
# 1         270       280.0       NaN       lge   NaN      E
# 2         160       160.0  DELAWARE       med   NaN      N
# 3         160       160.0  VIRGINIA       med   NaN      N
# 4          90       100.0  MARYLAND       lge   NaN      N
# ..        ...         ...       ...       ...   ...    ...
# 52         16        18.0      OHIO       NaN   NaN      N
# 53         18        20.0  MICHIGAN       NaN   NaN      N
# 54         16        16.0      OHIO       NaN   NaN      N
# 55         15        16.0      OHIO       NaN   NaN      N
# 56         15        18.0      OHIO       NaN   NaN      N
#
# [650 rows x 12 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
Northeast.agg('mean')
# Out:
# Type                 NaN
# Grade                NaN
# Low Price     136.790769
# High Price    153.453077
# dtype: float64

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
Market_avg = Northeast.groupby("City Name")
Market_avg

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
